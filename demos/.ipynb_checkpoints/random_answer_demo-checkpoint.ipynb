# %% [markdown]
# This is a demo notebook for the baseline VQA text method of **randomly** selecting an answer among the **top 1000 answers** of a training set.

# %%
# Add the path of the main directory
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from random_answer import RandomAnswer
from evaluate import Evaluate

# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataDir     = r"C:\Users\Nasser Benab\Documents\git\data\vqa"
versionType = "" 
taskType    = "OpenEnded" 
dataType    = "mscoco"
dataSubTypesTrain = ["train2014"]

# %% [markdown]
# # Training

# %%
# random answer method
rand_answer = RandomAnswer(dataDir, versionType, taskType, dataType, dataSubTypesTrain)
# Out:
# --> train2014
# loading VQA annotations and questions into memory...
# 0:00:48.953000
# creating index...
# index created!

# %%
# Compute the top 1000 answers of the training set
rand_answer.get_top_answers()

# %%
# Top 5 answers
rand_answer.top_answers[:5]
# Out:
# [u'yes', u'no', u'2', u'1', u'white']

# %% [markdown]
# # Predictions

# %%
# Predict answers on the validation dataset
dataSubType = "val2014"
rand_answer.predict(dataSubType)
# Out:
# loading VQA annotations and questions into memory...
# 0:00:12.730000
# creating index...
# index created!
# --> Saving the results

# %% [markdown]
# # Evaluation

# %%
# Compute the accuracies for the validation set
eval_ = Evaluate(rand_answer.vqa_test, rand_answer.results_file, rand_answer.quesFile_test, rand_answer.dataDir, 
                 rand_answer.dataType, dataSubType)
eval_.compute_accuracies()
# Out:
# Loading and preparing results...
# DONE (t=1.17s)
# creating index...
# index created!
# computing accuracy
# Finshed Percent: [####################] 99% Done computing accuracy
#
#
# Overall Accuracy: 0.12%

# %%
# Accuracy per answer type (%)
eval_.acc_answer_type_df
# Out:
#   Answer type  Accuracy
# 0      number      0.16
# 1      yes/no      0.13
# 2       other      0.11

# %%
# Accuracy per question type (%)
eval_.acc_question_type_df.head()
# Out:
#        Question type  Accuracy
# 0          are these      0.37
# 1       what is this      0.36
# 2  what is the woman      0.30
# 3      where are the      0.28
# 4     is this person      0.24

# %%
# Retrieve particular results
eval_.retrieve_result(question_type="how many people are")
# Out:
# Ground truth answers:
# ---------------------
# Question: How many people are there?
# Answer 1: 5
# Answer 2: 5
# Answer 3: 5
# Answer 4: 5
# Answer 5: 5
# Answer 6: 5
# Answer 7: 5
# Answer 8: 5
# Answer 9: 5
# Answer 10: 5
#
#
# Generated answer (accuracy 0.0%):
# ---------------------------------
# Answer: kite
